# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
dataset=pd.read_csv("C:/Users/mishr/Desktop/Advertising.csv",index_col=0)
dataset.shape
# Out:
# (200, 4)

# %%
dataset.head()
# Out:
#       TV  Radio  Newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
sns.pairplot(dataset,x_vars=['TV','Radio','Newspaper'],y_vars=['sales'],height=4 , aspect =0.9)

# %%
from sklearn.model_selection import train_test_split
feature_cols=['TV','Radio','Newspaper']
X=dataset[feature_cols]
y=dataset['sales']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(linreg.intercept_)
# Out:
# 2.9840369785589402

# %%
print(linreg.coef_)
# Out:
# [ 0.04593521  0.1850863  -0.00152064]

# %%
y_pred=linreg.predict(X_test)

# %%
print(y_pred)
print(y_test)
# Out:
# [16.36528856  9.36728585 19.60016013 12.82613894  7.39981865 10.1507892
#  24.04453141  8.88249258 17.73452864 13.92017011 12.41500687 14.30821082
#  15.67855222 12.39670494 12.3866775  12.01417423 16.25354153 17.49832766
#  17.23760224 21.79013094]
# 41     16.6
# 52     10.7
# 140    20.7
# 198    12.8
# 171     8.4
# 83     11.3
# 184    26.2
# 47     10.6
# 71     18.3
# 101    11.7
# 180    12.6
# 84     13.6
# 26     12.0
# 191    10.8
# 160    12.9
# 174    11.7
# 96     16.9
# 4      18.5
# 42     17.1
# 59     23.8
# Name: sales, dtype: float64

# %%
list(zip(feature_cols,linreg.coef_))
# Out:
# [('TV', 0.04593520582214795),
#  ('Radio', 0.1850863024509977),
#  ('Newspaper', -0.0015206374210719102)]
